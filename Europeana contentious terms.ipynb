# %%
import os # this module provides functions for interacting with the operating system
import pandas as pd # for data manipulation and analysis
import json # standard format inspired by JavaScript for data exchange and data transfer as text format over a network
from pprint import pprint # utility module that you can use to print data structures in a readable, pretty way
import re # regular expression syntax
import pyeuropeana.apis as apis # Europeana's search API

# %%
os.environ['EUROPEANA_API_KEY'] = 'amicaldtann'

# %%
termscounted = {}
terms = ["aborigine","aboriginal", "inboorling", "inlander", "indigène", "barbarian", "barbaar", "barbare", "barbares", 
         "berber", "berbers", "berbère", "berbères", "Bombay", "Colored","kleurling", "gekleurd","Coolie", "Koelie", 
         "disabled","handicaped", "crippled", "cripple", "cripples", "handicapé", "handicapés", "gehandicapten","infirme", 
         "infirmes", "invalide", "invalides", "eskimo", "eskimos", "Gypsy", "gypsies","Zigeuner", "Gitan", "gitans",
         "Bohémien","bohémiens", "bohémienne", "bohémiennes", "Hottentot", "Indian", "Indians", "Indiaan", "Indien", 
         "indiens", "Kaffir", "Kaffer", "Lappen","Lapp","Lapland", "Lapon", "Laponie", "Lapp", "Mohammedan","Moor",
         "Maure", "Mauresque", "Mulatto", "mulat", "mûlatre", "negro", "negroes", "neger", "negers", "nikker", "nègre",
         "négresse", "Oriental", "oosters", "oosterling", "Orientale", "orientals", "orientales", "orientaux","Planter", 
         "primitive", "primitief","primitif", "slave", "slaaf", "slaves","savage", "sauvage", "Événements d'Algérie",
         "Politionele Actie", "amulet", "amulette", "talisman", "bedeltje"]

# %%
for term in terms:
    response = apis.search(query=term)
    response.keys() #the result of the search is a dictionary 
    termscounted[term] = response["totalResults"] 
    print(term)
    print(response["totalResults"]) # the total number of items that the query returned
# Out:
# aborigine
# 39
# aboriginal
# 1076
# inboorling
# 15
# inlander
# 123
# indigène
# 1979
# barbarian
# 1143
# barbaar
# 14
# barbare
# 420
# barbares
# 344
# berber
# 2312
# berbers
# 235
# berbère
# 871
# berbères
# 943
# Bombay
# 6784
# Colored
# 18510
# kleurling
# 7
# gekleurd
# 8282
# Coolie
# 541
# Koelie
# 62
# disabled
# 3760
# handicaped
# 3
# crippled
# 542
# cripple
# 1573
# cripples
# 134
# handicapé
# 185
# handicapés
# 242
# gehandicapten
# 1119
# infirme
# 120
# infirmes
# 79
# invalide
# 1226
# invalides
# 5064
# eskimo
# 1386
# eskimos
# 243
# Gypsy
# 3565
# gypsies
# 1243
# Zigeuner
# 925
# Gitan
# 148
# gitans
# 433
# Bohémien
# 104
# bohémiens
# 695
# bohémienne
# 260
# bohémiennes
# 32
# Hottentot
# 835
# Indian
# 55507
# Indians
# 4271
# Indiaan
# 388
# Indien
# 104449
# indiens
# 2749
# Kaffir
# 548
# Kaffer
# 75
# Lappen
# 1514
# Lapp
# 9502
# Lapland
# 37827
# Lapon
# 1295
# Laponie
# 34155
# Lapp
# 9502
# Mohammedan
# 133
# Moor
# 26312
# Maure
# 911
# Mauresque
# 2026
# Mulatto
# 82
# mulat
# 330
# mûlatre
# 217
# negro
# 331462
# negroes
# 158
# neger
# 1304
# negers
# 233
# nikker
# 46
# nègre
# 54547
# négresse
# 310
# Oriental
# 137834
# oosters
# 1636
# oosterling
# 212
# Orientale
# 120715
# orientals
# 1676
# orientales
# 9300
# orientaux
# 1230
# Planter
# 3021
# primitive
# 3775
# primitief
# 126
# primitif
# 775
# slave
# 3980
# slaaf
# 665
# slaves
# 2451
# savage
# 2068
# sauvage
# 11885
# Événements d'Algérie
# 78
# Politionele Actie
# 445
# amulet
# 8835
# amulette
# 1613
# talisman
# 1095
# bedeltje
# 17

# %%
dict(sorted(termscounted.items(), key=lambda item: item[1]))
# Out:
# {'handicaped': 3,
#  'barbaar': 14,
#  'inboorling': 15,
#  'bedeltje': 17,
#  'bohémiennes': 32,
#  'nikker': 46,
#  'Koelie': 62,
#  'Kaffer': 75,
#  "Événements d'Algérie": 78,
#  'infirmes': 79,
#  'Mulatto': 82,
#  'Bohémien': 104,
#  'infirme': 120,
#  'Mohammedan': 133,
#  'cripples': 134,
#  'Gitan': 148,
#  'negroes': 158,
#  'handicapé': 185,
#  'mûlatre': 217,
#  'berbers': 235,
#  'handicapés': 242,
#  'eskimos': 243,
#  'bohémienne': 260,
#  'négresse': 310,
#  'barbares': 344,
#  'Indiaan': 388,
#  'barbare': 420,
#  'gitans': 433,
#  'Politionele Actie': 445,
#  'Coolie': 541,
#  'crippled': 542,
#  'Kaffir': 548,
#  'bohémiens': 695,
#  'primitif': 775,
#  'Hottentot': 835,
#  'berbère': 871,
#  'Maure': 911,
#  'Zigeuner': 925,
#  'berbères': 943,
#  'aboriginal': 1076,
#  'talisman': 1095,
#  'barbarian': 1143,
#  'invalide': 1226,
#  'orientaux': 1230,
#  'gypsies': 1242,
#  'Lapon': 1295,
#  'neger': 1304,
#  'eskimo': 1386,
#  'Lappen': 1525,
#  'cripple': 1573,
#  'amulette': 1613,
#  'orientals': 1676,
#  'indigène': 1979,
#  'Mauresque': 2026,
#  'savage': 2068,
#  'berber': 2312,
#  'slaves': 2451,
#  'indiens': 2749,
#  'Planter': 3021,
#  'Gypsy': 3565,
#  'disabled': 3760,
#  'primitive': 3775,
#  'slave': 3980,
#  'Indians': 4271,
#  'invalides': 5064,
#  'Bombay': 6784,
#  'amulet': 8835,
#  'orientales': 9300,
#  'Lapp': 9640,
#  'sauvage': 11885,
#  'Colored': 18510,
#  'Moor': 26311,
#  'Laponie': 34155,
#  'Lapland': 37827,
#  'nègre': 54547,
#  'Indian': 55507,
#  'Indien': 104463,
#  'Orientale': 120716,
#  'Oriental': 137836,
#  'negro': 331462}

# %%
response2 = apis.search(query=("slaves"), rows=4000)
response2.keys() 
count_data_provider = {} # create dictionary that will store the all the data providers and their count

print(len(response2['items'])) #we first perform a check and print the total result  
for item in response2['items']:
    print(item['country']) # for each item we print the country 
    print(item['dataProvider']) # and we also print the data priver
    dataprovider = item['dataProvider'][0]
    if dataprovider not in count_data_provider: #we add all the counts to the data provider dictionary 
        count_data_provider[dataprovider] = 1
    else:
        count_data_provider[dataprovider] += 1
# Out:
# 2451
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['Europe']
# ['The European Library']
# ['Slovenia']
# ['National and University Library of Slovenia']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Serbia']
# ['National Library of Serbia']
# ['Serbia']
# ['National Library of Serbia']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Hungary']
# ['National Szechenyi Library']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['Institute of Literary Research - PBI']
# ['Russia']
# ['Russian State Library']
# ['Russia']
# ['Russian State Library']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['Braginsky Collection']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Belgium']
# ['Free University of Brussels']
# ['Belgium']
# ['Free University of Brussels']
# ['Belgium']
# ['Free University of Brussels']
# ['Belgium']
# ['Royal Library of Belgium']
# ['Netherlands']
# ['Open Access Publishing in European Networks Foundation']
# ['Netherlands']
# ['Open Access Publishing in European Networks Foundation']
# ['Netherlands']
# ['Open Access Publishing in European Networks Foundation']
# ['Serbia']
# ['National Library of Serbia']
# ['Serbia']
# ['National Library of Serbia']
# ['Serbia']
# ['National Library of Serbia']
# ['Serbia']
# ['University library Svetozar Markovic, Belgrade']
# ['Austria']
# ['University of Vienna']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['Serbia']
# ['University library "Svetozar Markovic", Belgrade / Univerzitetska biblioteka "Svetozar Markovic", Beograd']
# ['Serbia']
# ['University library "Svetozar Markovic", Belgrade / Univerzitetska biblioteka "Svetozar Markovic", Beograd']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Sweden']
# ['Uppsala University']
# ['Sweden']
# ['Uppsala University']
# ['Sweden']
# ['Uppsala University']
# ['Sweden']
# ['Uppsala University']
# ['Sweden']
# ['Uppsala University']
# ['Sweden']
# ['Uppsala University']
# ['Sweden']
# ['Uppsala University']
# ['Sweden']
# ['Uppsala University']
# ['Sweden']
# ['Uppsala University']
# ['Sweden']
# ['Uppsala University']
# ['Sweden']
# ['Uppsala University']
# ['Sweden']
# ['Uppsala University']
# ['Spain']
# ['Complutense University of Madrid']
# ['Spain']
# ['Complutense University of Madrid']
# ['Spain']
# ['Complutense University of Madrid']
# ['Spain']
# ['Complutense University of Madrid']
# ['Europe']
# ['Uppsala University']
# ['Europe']
# ['Uppsala University']
# ['Europe']
# ['Uppsala University']
# ['Europe']
# ['Uppsala University']
# ['Europe']
# ['Uppsala University']
# ['Europe']
# ['Uppsala University']
# ['Sweden']
# ['The Museum of Mediterranean and Near Eastern Antiquities']
# ['Sweden']
# ['Museum of Ethnography']
# ['Sweden']
# ['Museum of Ethnography']
# ['Sweden']
# ['Museum of World Culture']
# ['Sweden']
# ['Museum of World Culture']
# ['United Kingdom']
# ['National Library of Scotland']
# ['Spain']
# ['Foundation Virtual Library Miguel de Cervantes']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Leiden University Libraries']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['Poland']
# ['Jan Kochanowski University in Kielce']
# ['Poland']
# ['Jan Kochanowski University in Kielce']
# ['Poland']
# ['Jan Kochanowski University in Kielce']
# ['Germany']
# ['Maya Image Archive - Image database of the project "Text Database and Dictionary of Classic Maya" at the University of Bonn - Department of Ancient American Studies and Ethnology']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Spain']
# ['RTVE']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['Netherlands']
# ["Atria, Institute on Gender Equality and Women's History"]
# ['Spain']
# ['Repositorio Institucional de la Universidad de Huelva']
# ['Spain']
# ['Repositorio Institucional de la Universidad de Huelva']
# ['Cyprus']
# ['Cyprus University of Technology']
# ['Switzerland']
# ['Association Films Plans-Fixes']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Spain']
# ['Ignacio Larramendi Foundation']
# ['Italy']
# ['Braidense National Library']
# ['Czech Republic']
# ['Map Collection UK']
# ['Czech Republic']
# ['Map Collection UK']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['Poland']
# ['Jagiellonian Digital Library']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['Italy']
# ['Braidense National Library']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['United Kingdom']
# ['National Library of Scotland']
# ['Georgia']
# ['Art Palace of Georgia']
# ['Georgia']
# ['Art Palace of Georgia']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Spain']
# ['Polytechnic University of Valencia']
# ['Greece']
# ['Academy of Athens']
# ['Greece']
# ['Academy of Athens']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['The Moravian Library in Brno']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Czech Republic']
# ['Library of the Czech Academy of Sciences']
# ['Belgium']
# ['Royal Museums of Art and History, Brussels']
# ['Greece']
# ['Greek National Opera']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Israel']
# ['National Library of Israel']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Belgium']
# ['Center of the Judeo-Moroccan Culture']
# ['Slovenia']
# ['National and University Library of Slovenia']
# ['Slovenia']
# ['National and University Library of Slovenia']
# ['Slovenia']
# ['National and University Library of Slovenia']
# ['Slovenia']
# ['National and University Library of Slovenia']
# ['Greece']
# ['American School of Classical Studies at Athens']
# ['Greece']
# ['Folklife and Ethnological Museum of Macedonia and Thrace']
# ['Sweden']
# ['Nationalmuseum Sweden']
# ['Germany']
# ['Ethnological Museum, Staatliche Museen zu Berlin']
# ['Europe']
# ['Nottingham City Museums and Galleries']
# ['Europe']
# ['Nottingham City Museums and Galleries']
# ['Europe']
# ['Nottingham City Museums and Galleries']
# ['Europe']
# ['Nottingham City Museums and Galleries']
# ['Europe']
# ['Nottingham City Museums and Galleries']
# ['Europe']
# ['Nottingham City Museums and Galleries']
# ['Europe']
# ['Nottingham City Museums and Galleries']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Italy']
# ['Internet Culturale']
# ['Italy']
# ['Internet Culturale']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ['The British Library']
# ['United Kingdom']
# ...
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Royal Museums Greenwich']
# ['United Kingdom']
# ['Imperial War Museums']
# ['United Kingdom']
# ['Imperial War Museums']
# ['United Kingdom']
# ['Imperial War Museums']
# ['United Kingdom']
# ['Picture the Past OAI feed']
# ['United Kingdom']
# ['Picture the Past OAI feed']
# ['United Kingdom']
# ['Picture the Past OAI feed']
# ['United Kingdom']
# ['Picture the Past OAI feed']
# ['United Kingdom']
# ['Kirklees Image Archive OAI Feed']
# ['United Kingdom']
# ['Museum of Archaeology and Anthropology (University of Cambridge), Cambridge, UK']
# ['United Kingdom']
# ['The Modern Records Centre, University of Warwick']
# ['United Kingdom']
# ['The Modern Records Centre, University of Warwick']
# ['United Kingdom']
# ['The Modern Records Centre, University of Warwick']
# ['United Kingdom']
# ['The Modern Records Centre, University of Warwick']
# ['United Kingdom']
# ['The Modern Records Centre, University of Warwick']
# ['United Kingdom']
# ['Trade Union Congress Library']
# ['United Kingdom']
# ['Trade Union Congress Library']
# ['United Kingdom']
# ['Trade Union Congress Library']
# ['Belgium']
# ['Amsab-Institute of Social History']
# ['Hungary']
# ['Open Society Archives at Central European University']
# ['Hungary']
# ['Open Society Archives at Central European University']
# ['Netherlands']
# ['Mauritshuis']
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Museum Rotterdam']
# ['Croatia']
# ['The Zagreb City Libraries']
# ['Finland']
# ['Finnish National Gallery']
# ['Finland']
# ['Finnish Heritage Agency']
# ['Finland']
# ['Society of Swedish Literature in Finland']
# ['Finland']
# ['Society of Swedish Literature in Finland']
# ['Finland']
# ['Society of Swedish Literature in Finland']
# ['Denmark']
# ['The Danish Agency for Culture']
# ['Netherlands']
# ['International Institute of Social History']
# ['Netherlands']
# ['International Institute of Social History']
# ['Netherlands']
# ['International Institute of Social History']
# ['Netherlands']
# ['International Institute of Social History']
# ['Netherlands']
# ['International Institute of Social History']
# ['France']
# ['Library of the Alliance Israélite Universelle']
# ['Greece']
# ['Hellenic Literary and Historical Archive - Cultural Foundation of the National Bank Of Greece']
# ['Greece']
# ['Hellenic Literary and Historical Archive - Cultural Foundation of the National Bank Of Greece']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Greece']
# ['Institute of Historical Research']
# ['Poland']
# ['Digital Library of the Maria Curie-Skłodowska University']
# ['Poland']
# ['Kuyavian-Pomeranian Digital Library']
# ['Poland']
# ['Malopolska Digital Library']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Lower Silesian Digital Library']
# ['Poland']
# ['Lower Silesian Digital Library']
# ['Poland']
# ['Lower Silesian Digital Library']
# ['Poland']
# ['Lower Silesian Digital Library']
# ['Poland']
# ['Lower Silesian Digital Library']
# ['Poland']
# ['Pomeranian Digital Library']
# ['Poland']
# ['Mazowsze Digital Library']
# ['Poland']
# ['Elbląska Digital Library']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['Europe']
# ['Bristol Museums, Galleries & Archives']
# ['United States of America']
# ['Harvard University, Museum of Comparative Zoology, Ernst Mayr Library']
# ['United States of America']
# ['Harvard University, Museum of Comparative Zoology, Ernst Mayr Library']
# ['United States of America']
# ['Harvard University, Museum of Comparative Zoology, Ernst Mayr Library']
# ['United States of America']
# ['Harvard University, Museum of Comparative Zoology, Ernst Mayr Library']
# ['United States of America']
# ['John Carter Brown Library (archive.org)']
# ['United States of America']
# ['Library of Congress']
# ['United States of America']
# ['University of California Libraries (archive.org)']
# ['United States of America']
# ['University of California Libraries (archive.org)']
# ['United States of America']
# ['John Carter Brown Library (archive.org)']
# ['United States of America']
# ['John Carter Brown Library (archive.org)']
# ['United States of America']
# ['John Carter Brown Library (archive.org)']
# ['United States of America']
# ['John Carter Brown Library (archive.org)']
# ['United States of America']
# ['John Carter Brown Library (archive.org)']
# ['United States of America']
# ['Research Library, The Getty Research Institute (archive.org)']
# ['United States of America']
# ['Emory University, Manuscript, Archives and Rare Book Library (archive.org)']
# ['United States of America']
# ['John Carter Brown Library (archive.org)']
# ['United States of America']
# ['Smithsonian Libraries']
# ['United States of America']
# ['Smithsonian Libraries']
# ['United States of America']
# ['Cornell University Library']
# ['Spain']
# ['Catalunya Film Archive']
# ['Lithuania']
# ['Lithuanian Central State Archives']
# ['United Kingdom']
# ['Imperial War Museums']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Istituto Luce - Cinecittà']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Slovakia']
# ['Slovak national gallery']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Royal Museum of Fine Arts Antwerp']
# ['Belgium']
# ['Royal Museum of Fine Arts Antwerp']
# ['Belgium']
# ['Royal Museum of Fine Arts Antwerp']
# ['Belgium']
# ['Royal Museum of Fine Arts Antwerp']
# ['Belgium']
# ['Royal Museum of Fine Arts Antwerp']
# ['Belgium']
# ['Royal Museum of Fine Arts Antwerp']
# ['Belgium']
# ['Royal Museum of Fine Arts Antwerp']
# ['France']
# ['Ministry of Culture']

# %%
dict(sorted(count_data_provider.items(), key=lambda item: item[1]))
# Out:
# {'The European Library': 1,
#  'National Szechenyi Library': 1,
#  'Institute of Literary Research - PBI': 1,
#  'Braginsky Collection': 1,
#  'Royal Library of Belgium': 1,
#  'University library Svetozar Markovic, Belgrade': 1,
#  'The Museum of Mediterranean and Near Eastern Antiquities': 1,
#  'Foundation Virtual Library Miguel de Cervantes': 1,
#  'Leiden University Libraries': 1,
#  'Maya Image Archive - Image database of the project "Text Database and Dictionary of Classic Maya" at the University of Bonn - Department of Ancient American Studies and Ethnology': 1,
#  'RTVE': 1,
#  "Atria, Institute on Gender Equality and Women's History": 1,
#  'Cyprus University of Technology': 1,
#  'Association Films Plans-Fixes': 1,
#  'Polytechnic University of Valencia': 1,
#  'The Moravian Library in Brno': 1,
#  'Royal Museums of Art and History, Brussels': 1,
#  'Greek National Opera': 1,
#  'American School of Classical Studies at Athens': 1,
#  'Folklife and Ethnological Museum of Macedonia and Thrace': 1,
#  'Nationalmuseum Sweden': 1,
#  'Ethnological Museum, Staatliche Museen zu Berlin': 1,
#  'Library of Cyprus University of Technology': 1,
#  'Netherlands Institute for Sound and Vision': 1,
#  'National Audiovisual Archive of Hungary': 1,
#  'Belgian Radio-television of the French Community': 1,
#  'Danish Broadcasting Corporation': 1,
#  'Fashion Museum of Antwerp': 1,
#  'Metropolitan Ervin Szabó Library': 1,
#  'Balaton Museum - Keszthely': 1,
#  'Hungarian Theatre Museum and Institute': 1,
#  'Wakefield Council': 1,
#  'Royal Albert Memorial Museum & Art Gallery': 1,
#  'Burns Scotland': 1,
#  'The Israel Museum, Jerusalem': 1,
#  'United Archives': 1,
#  'United Archives / WHA': 1,
#  'Kirklees Image Archive OAI Feed': 1,
#  'Museum of Archaeology and Anthropology (University of Cambridge), Cambridge, UK': 1,
#  'Amsab-Institute of Social History': 1,
#  'Mauritshuis': 1,
#  'The Zagreb City Libraries': 1,
#  'Finnish National Gallery': 1,
#  'Finnish Heritage Agency': 1,
#  'The Danish Agency for Culture': 1,
#  'Library of the Alliance Israélite Universelle': 1,
#  'Digital Library of the Maria Curie-Skłodowska University': 1,
#  'Kuyavian-Pomeranian Digital Library': 1,
#  'Malopolska Digital Library': 1,
#  'Pomeranian Digital Library': 1,
#  'Mazowsze Digital Library': 1,
#  'Elbląska Digital Library': 1,
#  'Library of Congress': 1,
#  'Research Library, The Getty Research Institute (archive.org)': 1,
#  'Emory University, Manuscript, Archives and Rare Book Library (archive.org)': 1,
#  'Cornell University Library': 1,
#  'Catalunya Film Archive': 1,
#  'Lithuanian Central State Archives': 1,
#  'Istituto Luce - Cinecittà': 1,
#  'Slovak national gallery': 1,
#  'Ministry of Culture': 1,
#  'Russian State Library': 2,
#  'University of Vienna': 2,
#  'University library "Svetozar Markovic", Belgrade / Univerzitetska biblioteka "Svetozar Markovic", Beograd': 2,
#  'Museum of Ethnography': 2,
#  'Museum of World Culture': 2,
#  'Repositorio Institucional de la Universidad de Huelva': 2,
#  'Braidense National Library': 2,
#  'Art Palace of Georgia': 2,
#  'Academy of Athens': 2,
#  'Internet Culturale': 2,
#  'Roman Inscriptions of Britain': 2,
#  'German National Library': 2,
#  'Central Library of the Bulgarian Academy of Sciences': 2,
#  'Catholic University of Leuven': 2,
#  'Open Society Archives at Central European University': 2,
#  'Hellenic Literary and Historical Archive - Cultural Foundation of the National Bank Of Greece': 2,
#  'University of California Libraries (archive.org)': 2,
#  'Smithsonian Libraries': 2,
#  'Free University of Brussels': 3,
#  'Open Access Publishing in European Networks Foundation': 3,
#  'Jan Kochanowski University in Kielce': 3,
#  'Map Collection UK': 3,
#  'The Language Archive': 3,
#  'Museum Rotterdam': 3,
#  'Jersey Heritage': 3,
#  'Trade Union Congress Library': 3,
#  'Society of Swedish Literature in Finland': 3,
#  'National Library of the Czech Republic': 4,
#  'Complutense University of Madrid': 4,
#  'IMSLP/Petrucci Music Library': 4,
#  'Victoria and Albert Museum': 4,
#  'Imperial War Museums': 4,
#  'Picture the Past OAI feed': 4,
#  'Harvard University, Museum of Comparative Zoology, Ernst Mayr Library': 4,
#  'National and University Library of Slovenia': 5,
#  'National Library of Serbia': 5,
#  'TopFoto': 5,
#  'National Library of Spain': 5,
#  'The Modern Records Centre, University of Warwick': 5,
#  'Lower Silesian Digital Library': 5,
#  'City of Music': 6,
#  'National Library of the Netherlands': 7,
#  'Nottingham City Museums and Galleries': 7,
#  'Deutsche Welle': 7,
#  'International Institute of Social History': 7,
#  'Bristol Museums, Galleries & Archives': 7,
#  'John Carter Brown Library (archive.org)': 7,
#  'Royal Museum of Fine Arts Antwerp': 7,
#  'Austrian National Library': 8,
#  'Research deposit of the University of Seville': 8,
#  'National Audiovisual Institute France': 9,
#  'Hellenic Broadcasting Corporation': 9,
#  'Italian Geographical Society Photo-Archive': 9,
#  'RBB AIT DISMARC': 10,
#  'DFF – German Film Institute & Film Museum': 10,
#  'Heidelberg University Library': 11,
#  'TV3 Catalan Television': 11,
#  'GESIS - Leibniz Institute for the Social Sciences. Library Cologne': 11,
#  'Institute for War-, Holocaust- and Genocidestudies': 12,
#  'American Jewish Historical Society': 12,
#  'Ghent University Library': 12,
#  'Aikaterini Laskaridis Foundation': 13,
#  'PMR Maeyaert': 13,
#  'Digital Repository Research Institutes': 13,
#  'Horniman Museum and Gardens': 15,
#  'The Portable Antiquities Scheme': 15,
#  'Documentary Repository of the University of Salamanca': 15,
#  'Film Library of Bologna': 16,
#  'Institute of Historical Research': 17,
#  'Uppsala University': 18,
#  'National Library of Scotland': 19,
#  'National Library of Poland': 20,
#  'Luce Institute': 23,
#  'Jagiellonian Digital Library': 24,
#  'Library of the Czech Academy of Sciences': 27,
#  'Center of the Judeo-Moroccan Culture': 29,
#  'National Library of Israel': 30,
#  'Wellcome Collection': 33,
#  'Bavarian State Library': 38,
#  'Royal Museums Greenwich': 47,
#  'Rijksmuseum': 48,
#  'Ignacio Larramendi Foundation': 72,
#  'Bodleian Libraries, University of Oxford': 108,
#  'National Library of France': 123,
#  'Greater Digital Library': 124,
#  'Promoter Digital Gallery': 173,
#  'National Museum of World Cultures Foundation': 274,
#  'The British Library': 735}

# %%
response3 = apis.search(query="slave", rows=4000)
response3.keys() 
count_data_provider = {}
for item in response3['items']:
    print(item['country'])
    print(item['dataProvider'])
    dataprovider = item['dataProvider'][0]
    if dataprovider not in count_data_provider:
        count_data_provider[dataprovider] = 1
    else:
        count_data_provider[dataprovider] += 1
print(len(response3['items']))
# Out:
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['Europe']
# ['The European Library']
# ['Slovenia']
# ['National and University Library of Slovenia']
# ['Slovenia']
# ['National and University Library of Slovenia']
# ['Slovenia']
# ['National and University Library of Slovenia']
# ['Serbia']
# ['National Library of Serbia']
# ['Serbia']
# ['National Library of Serbia']
# ['Serbia']
# ['National Library of Serbia']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Denmark']
# ['The Royal Library: The National Library of Denmark and Copenhagen University Library']
# ['Denmark']
# ['The Royal Library: The National Library of Denmark and Copenhagen University Library']
# ['Denmark']
# ['The Royal Library: The National Library of Denmark and Copenhagen University Library']
# ['Denmark']
# ['The Royal Library: The National Library of Denmark and Copenhagen University Library']
# ['Denmark']
# ['The Royal Library: The National Library of Denmark and Copenhagen University Library']
# ['Denmark']
# ['The Royal Library: The National Library of Denmark and Copenhagen University Library']
# ['Denmark']
# ['The Royal Library: The National Library of Denmark and Copenhagen University Library']
# ['Denmark']
# ['The Royal Library: The National Library of Denmark and Copenhagen University Library']
# ['Denmark']
# ['The Royal Library: The National Library of Denmark and Copenhagen University Library']
# ['Denmark']
# ['The Royal Library: The National Library of Denmark and Copenhagen University Library']
# ['Denmark']
# ['The Royal Library: The National Library of Denmark and Copenhagen University Library']
# ['Denmark']
# ['The Royal Library: The National Library of Denmark and Copenhagen University Library']
# ['Denmark']
# ['The Royal Library: The National Library of Denmark and Copenhagen University Library']
# ['Hungary']
# ['National Szechenyi Library']
# ['Hungary']
# ['National Szechenyi Library']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['United Kingdom']
# ['Wellcome Collection']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['Iceland']
# ['National and University Library of Iceland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Russia']
# ['Russian State Library']
# ['Denmark']
# ['National Library of Denmark']
# ['Croatia']
# ['Croatian Academy of Sciences and Arts']
# ['Croatia']
# ['Croatian Academy of Sciences and Arts']
# ['Croatia']
# ['Croatian Academy of Sciences and Arts']
# ['Romania']
# ['Lucian Blaga Central University Library, Cluj-Napoca, Romania']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Italy']
# ['European Library of Information and Culture']
# ['Italy']
# ['European Library of Information and Culture']
# ['Italy']
# ['European Library of Information and Culture']
# ['Italy']
# ['European Library of Information and Culture']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['Croatia']
# ['National and University Library in Zagreb']
# ['Croatia']
# ['Croatian Academy of Sciences and Arts']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Belgium']
# ['Royal Library of Belgium']
# ['United Kingdom']
# ['University of Edinburgh']
# ['United Kingdom']
# ['University of Edinburgh']
# ['United Kingdom']
# ['University of Edinburgh']
# ['United Kingdom']
# ['University of Edinburgh']
# ['United Kingdom']
# ['University of Edinburgh']
# ['United Kingdom']
# ['University of Edinburgh']
# ['Netherlands']
# ['Open Access Publishing in European Networks Foundation']
# ['Netherlands']
# ['Open Access Publishing in European Networks Foundation']
# ['Netherlands']
# ['Open Access Publishing in European Networks Foundation']
# ['Netherlands']
# ['Open Access Publishing in European Networks Foundation']
# ['Netherlands']
# ['Open Access Publishing in European Networks Foundation']
# ['Netherlands']
# ['Open Access Publishing in European Networks Foundation']
# ['Netherlands']
# ['Open Access Publishing in European Networks Foundation']
# ['Netherlands']
# ['Open Access Publishing in European Networks Foundation']
# ['Netherlands']
# ['Open Access Publishing in European Networks Foundation']
# ['Serbia']
# ['National Library of Serbia']
# ['Serbia']
# ['National Library of Serbia']
# ['Serbia']
# ['National Library of Serbia']
# ['Serbia']
# ['National Library of Serbia']
# ['Serbia']
# ['National Library of Serbia']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['Croatia']
# ['University of Zagreb. Catholic Faculty of  Theology. Department of the History of Christian Literature and Christian Teaching.']
# ['Serbia']
# ...
# ['Netherlands']
# ['Naturalis Biodiversity Center']
# ['Netherlands']
# ['Naturalis Biodiversity Center']
# ['Netherlands']
# ['Naturalis Biodiversity Center']
# ['Netherlands']
# ['Naturalis Biodiversity Center']
# ['Germany']
# ['Natural History Museum, Berlin']
# ['United Kingdom']
# ['The Trustees of the Natural History Museum, London']
# ['United Kingdom']
# ['The Trustees of the Natural History Museum, London']
# ['United Kingdom']
# ['The Trustees of the Natural History Museum, London']
# ['United Kingdom']
# ['The Trustees of the Natural History Museum, London']
# ['United Kingdom']
# ['The Trustees of the Natural History Museum, London']
# ['United Kingdom']
# ['The Trustees of the Natural History Museum, London']
# ['United Kingdom']
# ['The Trustees of the Natural History Museum, London']
# ['United Kingdom']
# ['Royal Botanic Gardens Kew']
# ['United Kingdom']
# ['Royal Botanic Gardens Kew']
# ['United Kingdom']
# ['Royal Botanic Gardens Kew']
# ['United Kingdom']
# ['Royal Botanic Gardens Kew']
# ['United Kingdom']
# ['Royal Botanic Gardens Kew']
# ['United Kingdom']
# ['Royal Botanic Gardens Kew']
# ['United Kingdom']
# ['Royal Botanic Gardens Kew']
# ['United Kingdom']
# ['Royal Botanic Gardens Kew']
# ['United Kingdom']
# ['Royal Botanic Gardens Kew']
# ['United Kingdom']
# ['Royal Botanic Gardens Kew']
# ['United Kingdom']
# ['Royal Botanic Gardens Kew']
# ['United Kingdom']
# ['Royal Botanic Gardens Kew']
# ['Portugal']
# ['National Library of Portugal']
# ['Portugal']
# ['National Library of Portugal']
# ['Portugal']
# ['National Library of Portugal']
# ['Portugal']
# ['National Library of Portugal']
# ['Portugal']
# ['National Library of Portugal']
# ['Portugal']
# ['National Library of Portugal']
# ['Portugal']
# ['National Library of Portugal']
# ['Portugal']
# ['National Library of Portugal']
# ['Poland']
# ['Radom Digital Library']
# ['Poland']
# ['Radom Digital Library']
# ['Poland']
# ['Digital Library of the Maria Curie-Skłodowska University']
# ['Poland']
# ['Digital Library of the Maria Curie-Skłodowska University']
# ['Poland']
# ['Malopolska Digital Library']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Repository Research Institutes']
# ['Poland']
# ['Digital Library of the Wroclaw University']
# ['Poland']
# ['Digital Library of the Wroclaw University']
# ['Poland']
# ['Podkarpacka Digital Library']
# ['Poland']
# ['West Pomeranian Digital Library "Pomerania"']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Greater Digital Library']
# ['Poland']
# ['Pomeranian Digital Library']
# ['Poland']
# ['Pomeranian Digital Library']
# ['Poland']
# ['Pomeranian Digital Library']
# ['Poland']
# ['Pomeranian Digital Library']
# ['Poland']
# ['Pomeranian Digital Library']
# ['Poland']
# ['Pomeranian Digital Library']
# ['Poland']
# ['Pomeranian Digital Library']
# ['Poland']
# ['Pomeranian Digital Library']
# ['Poland']
# ['Mazowsze Digital Library']
# ['Poland']
# ['E-library of Warsaw University']
# ['Poland']
# ['E-library of Warsaw University']
# ['Austria']
# ['University of Graz']
# ['Austria']
# ['University of Graz']
# ['Austria']
# ['University of Graz']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['American Jewish Historical Society']
# ['United States of America']
# ['Leo Baeck Institute, Center for Jewish History']
# ['United States of America']
# ['Leo Baeck Institute, Center for Jewish History']
# ['United States of America']
# ['Leo Baeck Institute, Center for Jewish History']
# ['United States of America']
# ['Leo Baeck Institute, Center for Jewish History']
# ['United States of America']
# ['Leo Baeck Institute, Center for Jewish History']
# ['Austria']
# ['University Library of Humboldt University of Berlin']
# ['United States of America']
# ['University of Toronto - Robarts Library']
# ['United States of America']
# ['University of California Libraries (archive.org)']
# ['United States of America']
# ['University of California Libraries (archive.org)']
# ['United States of America']
# ['University of Alberta Libraries (archive.org)']
# ['United States of America']
# ['University of Alberta Libraries (archive.org)']
# ['United States of America']
# ['John Carter Brown Library (archive.org)']
# ['United States of America']
# ['John Carter Brown Library (archive.org)']
# ['United States of America']
# ['University of Alberta Libraries (archive.org)']
# ['United States of America']
# ['John Carter Brown Library (archive.org)']
# ['United States of America']
# ['Smithsonian Libraries']
# ['United States of America']
# ['Smithsonian Libraries']
# ['United States of America']
# ['Smithsonian Libraries']
# ['United States of America']
# ['Smithsonian Libraries']
# ['United States of America']
# ['Naturalis Biodiversity Center']
# ['United States of America']
# ['University of Alberta Libraries (archive.org)']
# ['United States of America']
# ['University of Alberta Libraries (archive.org)']
# ['United States of America']
# ['University of Alberta Libraries (archive.org)']
# ['United States of America']
# ['University of Alberta Libraries (archive.org)']
# ['United States of America']
# ['University of Alberta Libraries (archive.org)']
# ['United States of America']
# ['Princeton Theological Seminary Library (archive.org)']
# ['United States of America']
# ['University of Alberta Libraries (archive.org)']
# ['United States of America']
# ['Smithsonian Libraries']
# ['United States of America']
# ['John Carter Brown Library (archive.org)']
# ['United States of America']
# ['Smithsonian Libraries']
# ['United States of America']
# ['Canadiana.org (archive.org)']
# ['United States of America']
# ['Research Library, The Getty Research Institute (archive.org)']
# ['United States of America']
# ['Cornell University Library']
# ['United States of America']
# ['Library of Congress']
# ['United States of America']
# ['Library of Congress']
# ['United States of America']
# ['Library of Congress']
# ['Serbia']
# ['The Yugoslav Film Archive']
# ['Czech Republic']
# ['National Film Archive']
# ['Netherlands']
# ['EYE Film Museum']
# ['Finland']
# ['National Audiovisual Institute']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Italy']
# ['Film Library of Bologna']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Germany']
# ['DFF – German Film Institute & Film Museum']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Italy']
# ['Luce Institute']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Slovakia']
# ['Slovak national gallery']
# ['Slovakia']
# ['Slovak national gallery']
# ['Slovakia']
# ['Slovak national gallery']
# ['Slovakia']
# ['Slovak national gallery']
# ['Romania']
# ['Colecția muzeală a Arhiepiscopiei Ortodoxe - ALBA IULIA']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['Romania']
# ['Romanian Academy Library']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['France']
# ['National Audiovisual Institute France']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Museum of Fine Arts Ghent']
# ['Belgium']
# ['Groeninge Museum Bruges']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# 3980

# %%
dict(sorted(count_data_provider.items(), key=lambda item: item[1]))
# Out:
# {'The European Library': 1,
#  'National and University Library of Iceland': 1,
#  'Russian State Library': 1,
#  'National Library of Denmark': 1,
#  'Lucian Blaga Central University Library, Cluj-Napoca, Romania': 1,
#  'National and University Library in Zagreb': 1,
#  'Royal Library of Belgium': 1,
#  'University of Zagreb. Catholic Faculty of  Theology. Department of the History of Christian Literature and Christian Teaching.': 1,
#  'Naval Museum': 1,
#  'Institute of Research and Acoustic Coordination/Music': 1,
#  'Leiden University Libraries': 1,
#  'Museene for kystkultur og gjenreisning i Finnmark IKS': 1,
#  'Zemský archiv Opava, pobočka Olomouc': 1,
#  'Digital Memory of Catalonia': 1,
#  'National Museum in Warsaw': 1,
#  'C-DaRE (Centre for Dance Research), COVUNI and Early Dance Circle  (EDC)': 1,
#  'Media library of Art and Visual History of Humboldt University of Berlin': 1,
#  'Repositorio Institucional de la Universidad de Huelva': 1,
#  'Association Films Plans-Fixes': 1,
#  'Historical Museum': 1,
#  'AECID Digital Library': 1,
#  'https://uri.hr/indigo/org:muo': 1,
#  'Polytechnic University of Valencia': 1,
#  'Academy of Sciences Library/Knihovna Akademie věd ČR': 1,
#  'The Moravian Library in Brno': 1,
#  'National Research Foundation Eleftherios K. Venizelos': 1,
#  'Transport Infrastructure Ireland': 1,
#  'Frankfurt University Library': 1,
#  'Bulgarian Academy of Sciences, Institute of Art Studies': 1,
#  'Open University of Cyprus': 1,
#  'Europeana Foundation': 1,
#  'Leo Baeck Institute/Center for Jewish History': 1,
#  'Benaki Museum': 1,
#  'Toy Museum of the City of Nuremberg': 1,
#  'Rhône-Alpes Laboratory for Historical Research': 1,
#  'Tobar an Dualchais - Sabhal Mòr Ostaig': 1,
#  'LMTA': 1,
#  'Southwestbrabants Museum': 1,
#  'National Media Museum, United Kingdom': 1,
#  'Postal Cabinet Museum of Barcelona (Marull’s Collection)': 1,
#  'Polish Television': 1,
#  'Romanian Television': 1,
#  'National Archives of the Netherlands': 1,
#  'Bezalel Academy of Arts and Design': 1,
#  'Shoes or no shoes': 1,
#  'Centraal Museum Utrecht': 1,
#  'Victoria and Albert Museum': 1,
#  'Hungarian National Digital Archive and Film Institute': 1,
#  'Metropolitan Ervin Szabó Library': 1,
#  'Balaton Museum - Keszthely': 1,
#  'Holocaust Documentation Center and Memorial Collection Public Foundation - Budapest': 1,
#  'Hungarian Franciscan Library and Archives - Budapest': 1,
#  'Royal Albert Memorial Museum & Art Gallery': 1,
#  'Gleimhaus in Halberstadt': 1,
#  'Luigi Sturzo Institute': 1,
#  'Central Library of the Bulgarian Academy of Sciences': 1,
#  'Royal Institute for Cultural Heritage': 1,
#  'Royal Museums of Fine Arts of Belgium': 1,
#  'National Academic Library and Information System Foundation': 1,
#  'Geological and Mineralogical Museum of the University of Kiel': 1,
#  'East Bohemian Museum in Pardubice': 1,
#  'Ivan Potrč Library Ptuj': 1,
#  'Pavel Golia Library Trebnje': 1,
#  'Beno Zupančič Library Postojna': 1,
#  'Regional Archives Maribor': 1,
#  'Miran Jarc Library Novo Mesto': 1,
#  'Koroška osrednja knjižnica  dr. Franca Sušnika': 1,
#  'Imperial War Museums': 1,
#  'Lincolnshire County Council': 1,
#  'Museum of Archaeology and Anthropology (University of Cambridge), Cambridge, UK': 1,
#  'Documentation Center Museum for the Performing Arts Theater Institute of Barcelona, ITB, Barcelona, Spain': 1,
#  'Trade Union Congress Library': 1,
#  'Martynas Mažvydas National Library of Lithuania': 1,
#  'Museon': 1,
#  'National Museum of Antiquities': 1,
#  'Finnish National Gallery': 1,
#  'Archaeology Data Service': 1,
#  'Leibniz Institute for Regional Geography': 1,
#  'German Documentation Center for Art History - Marburg Picture Index': 1,
#  'Albertina': 1,
#  'Library of the Alliance Israélite Universelle': 1,
#  'Natural History Museum, Berlin': 1,
#  'Malopolska Digital Library': 1,
#  'Podkarpacka Digital Library': 1,
#  'West Pomeranian Digital Library "Pomerania"': 1,
#  'Mazowsze Digital Library': 1,
#  'University Library of Humboldt University of Berlin': 1,
#  'University of Toronto - Robarts Library': 1,
#  'Princeton Theological Seminary Library (archive.org)': 1,
#  'Canadiana.org (archive.org)': 1,
#  'Research Library, The Getty Research Institute (archive.org)': 1,
#  'Cornell University Library': 1,
#  'The Yugoslav Film Archive': 1,
#  'National Film Archive': 1,
#  'EYE Film Museum': 1,
#  'National Audiovisual Institute': 1,
#  'Colecția muzeală a Arhiepiscopiei Ortodoxe - ALBA IULIA': 1,
#  'Museum of Fine Arts Ghent': 1,
#  'Groeninge Museum Bruges': 1,
#  'Ministry of Culture': 1,
#  'National Szechenyi Library': 2,
#  'University library "Svetozar Markovic", Belgrade / Univerzitetska biblioteka "Svetozar Markovic", Beograd': 2,
#  'Museum of Ethnography': 2,
#  'Nordic Museum Foundation': 2,
#  'International Maritime Museum': 2,
#  'Jan Kochanowski University in Kielce': 2,
#  'ERIAC': 2,
#  'State and University Library': 2,
#  'Thyssen-Bornemisza Museum': 2,
#  'National Science and Media Museum Bradford': 2,
#  'Pucci Archive': 2,
#  'Count Károly Esterházy Mansion and County Museum - Pápa': 2,
#  'United Archives / WHA': 2,
#  "Centre for History and Analysis of Recorded Music, King's College London; United Kingdom": 2,
#  'Leodis - A photographic archive of Leeds': 2,
#  'Kirklees Image Archive OAI Feed': 2,
#  'A. Baranauskas Granary and A. Vienuolis-Žukauskas Memorial House-Museum': 2,
#  'Leo Smit foundation': 2,
#  'Zeeland library': 2,
#  'Teylers Museum': 2,
#  'Society of Swedish Literature in Finland': 2,
#  'World Museum Vienna': 2,
#  'Radom Digital Library': 2,
#  'Digital Library of the Maria Curie-Skłodowska University': 2,
#  'Digital Library of the Wroclaw University': 2,
#  'E-library of Warsaw University': 2,
#  'University of California Libraries (archive.org)': 2,
#  'Herzog Anton Ulrich Museum': 3,
#  'The Institute of the Lithuanian Language': 3,
#  'Map Collection UK': 3,
#  'Municipal Library of Prague': 3,
#  'Nottingham City Museums and Galleries': 3,
#  'RTV Slovenia': 3,
#  'Jersey Heritage': 3,
#  'Burns Scotland': 3,
#  'Ljubljana City Library': 3,
#  'Goriška knjižnica Franceta Bevka Nova Gorica': 3,
#  'Cumbria Archives and Local Studies Department': 3,
#  'The Modern Records Centre, University of Warwick': 3,
#  'University of Cyprus': 3,
#  'Slovenian music information centre': 3,
#  'University of Graz': 3,
#  'Library of Congress': 3,
#  'Media Library of Architecture and Heritage': 3,
#  'Croatian Academy of Sciences and Arts': 4,
#  'European Library of Information and Culture': 4,
#  'Complutense University of Madrid': 4,
#  'The Oireachtas Library & Research Service': 4,
#  'Center for Research in Ethnomusicology': 4,
#  'Vindolanda Tablets Online': 4,
#  'Netherlands Institute for Sound and Vision': 4,
#  'The Israel Museum, Jerusalem': 4,
#  'United Archives': 4,
#  'Liber Liber, Rome, Italy': 4,
#  'Digital Mechanism and Gear Library': 4,
#  'John Carter Brown Library (archive.org)': 4,
#  'Slovak national gallery': 4,
#  'Museum of World Culture': 5,
#  'Jewish Historical Museum': 5,
#  'Catholic University of Leuven': 5,
#  'KAMRA': 5,
#  'Overloon War Museum': 5,
#  'Leo Baeck Institute, Center for Jewish History': 5,
#  'University of Edinburgh': 6,
#  'The Museum of Mediterranean and Near Eastern Antiquities': 6,
#  'Library of The Jewish Theological Seminary': 6,
#  'University of Bologna': 6,
#  'German National Library': 6,
#  'Horniman Museum and Gardens': 6,
#  'TopFoto': 6,
#  'Hellenic Literary and Historical Archive - Cultural Foundation of the National Bank Of Greece': 6,
#  'Smithsonian Libraries': 6,
#  'National Library of the Czech Republic': 7,
#  'Museum of Arts and Crafts, Zagreb': 7,
#  'The Trustees of the Natural History Museum, London': 7,
#  'American Jewish Historical Society': 7,
#  'National Library of Serbia': 8,
#  'National Heritage Institute, Bucharest': 8,
#  'Center of the Judeo-Moroccan Culture': 8,
#  'Roman Inscriptions of Britain': 8,
#  'National Library of Portugal': 8,
#  'Pomeranian Digital Library': 8,
#  'Open Access Publishing in European Networks Foundation': 9,
#  'The Danish Agency for Culture': 9,
#  'Danish Broadcasting Corporation': 9,
#  'Picture the Past OAI feed': 9,
#  'Digital Repository Research Institutes': 9,
#  'University of Alberta Libraries (archive.org)': 9,
#  'RBB AIT DISMARC': 10,
#  'TV3 Catalan Television': 10,
#  'Allard Pierson': 10,
#  'DFF – German Film Institute & Film Museum': 10,
#  'Ghent University Library': 10,
#  'Hellenic Broadcasting Corporation': 11,
#  'National Library of the Netherlands': 12,
#  'City of Music': 12,
#  'Internet Culturale': 12,
#  'National Gallery of Denmark': 12,
#  'Royal Botanic Gardens Kew': 12,
#  'The Royal Library: The National Library of Denmark and Copenhagen University Library': 13,
#  'Deutsche Fotothek': 14,
#  'Documentary Repository of the University of Salamanca': 14,
#  'Bristol Museums, Galleries & Archives': 14,
#  'Research deposit of the University of Seville': 15,
#  'Egypt Centre': 16,
#  'Royal Museums of Art and History, Brussels': 18,
#  'Deutsche Welle': 19,
#  'IMSLP/Petrucci Music Library': 20,
#  'National Library of Spain': 20,
#  'National Library of Poland': 21,
#  'The Portable Antiquities Scheme': 22,
#  'Romanian Academy Library': 22,
#  'National and University Library of Slovenia': 24,
#  'Austrian National Library': 24,
#  'Braidense National Library': 24,
#  'Heidelberg University Library': 25,
#  'Rijksmuseum': 26,
#  'Luce Institute': 26,
#  'Italian Geographical Society Photo-Archive': 26,
#  'National Library of Scotland': 29,
#  'The Digital Network of Museum Collections in Spain': 29,
#  'Film Library of Bologna': 30,
#  'Naturalis Biodiversity Center': 32,
#  'Wellcome Collection': 38,
#  'Uppsala University': 39,
#  'National Library of Israel': 40,
#  'National Audiovisual Institute France': 40,
#  'Jagiellonian Digital Library': 41,
#  'Library of the Czech Academy of Sciences': 41,
#  'The Language Archive': 43,
#  'Institute for War-, Holocaust- and Genocidestudies': 48,
#  'Bavarian State Library': 61,
#  'Ignacio Larramendi Foundation': 72,
#  'Open Society Archives at Central European University': 72,
#  'Greater Digital Library': 75,
#  'Aikaterini Laskaridis Foundation': 82,
#  'GESIS - Leibniz Institute for the Social Sciences. Library Cologne': 84,
#  'Royal Museums Greenwich': 102,
#  'Academy of Athens': 116,
#  'Institute of Historical Research': 119,
#  'National Museum of World Cultures Foundation': 140,
#  'Internet Archive': 147,
#  'Schola Graphidis Art Collection, Budapest': 158,
#  'National Library of France': 259,
#  'Bodleian Libraries, University of Oxford': 491,
#  'The British Library': 557}

# %%
response4 = apis.search(query="bohémien*", rows=5000)
response4.keys() 
count_data_provider = {}

print(len(response4['items']))
for item in response4['items']:
    print(item['country'])
    print(item['dataProvider'])
    dataprovider = item['dataProvider'][0]
    if dataprovider not in count_data_provider:
        count_data_provider[dataprovider] = 1
    else:
        count_data_provider[dataprovider] += 1
# Out:
# 1090
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Hungary']
# ['National Szechenyi Library']
# ['United Kingdom']
# ['Wellcome Collection']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Institute for Art History Library']
# ['France']
# ['National Institute for Art History Library']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Poland']
# ['National Library of Poland']
# ['Russia']
# ['Russian State Library']
# ['Russia']
# ['Russian State Library']
# ['Russia']
# ['Russian State Library']
# ['Russia']
# ['Russian State Library']
# ['Russia']
# ['Russian State Library']
# ['Russia']
# ['Russian State Library']
# ['Russia']
# ['Russian State Library']
# ['Russia']
# ['Russian State Library']
# ['Russia']
# ['Russian State Library']
# ['Russia']
# ['Russian State Library']
# ['Russia']
# ['Russian State Library']
# ['Romania']
# ['Lucian Blaga Central University Library, Cluj-Napoca, Romania']
# ['Hungary']
# ['The University and National Library of Debrecen']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Czech Republic']
# ['National Library of the Czech Republic']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Austria']
# ['Austrian National Library']
# ['Belgium']
# ['Ghent University Library']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['United Kingdom']
# ['Bodleian Libraries, University of Oxford']
# ['Europe']
# ['Uppsala University']
# ['Sweden']
# ['Örebro County Museum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Netherlands']
# ['Rijksmuseum']
# ['Germany']
# ['Herzog Anton Ulrich Museum']
# ['Germany']
# ['Herzog Anton Ulrich Museum']
# ['Germany']
# ['Herzog Anton Ulrich Museum']
# ['Germany']
# ['Herzog Anton Ulrich Museum']
# ['Germany']
# ['Herzog Anton Ulrich Museum']
# ['Germany']
# ['Herzog Anton Ulrich Museum']
# ['Germany']
# ['Herzog Anton Ulrich Museum']
# ['Germany']
# ['Herzog Anton Ulrich Museum']
# ['Germany']
# ['Herzog Anton Ulrich Museum']
# ['Germany']
# ['Herzog Anton Ulrich Museum']
# ['Germany']
# ['Herzog Anton Ulrich Museum']
# ['Germany']
# ['Herzog Anton Ulrich Museum']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['France']
# ['National Library of France']
# ['Spain']
# ['Digital Memory of Catalonia']
# ['Germany']
# ['Baden State Library']
# ['Germany']
# ['Baden State Library']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['France']
# ['City of Music']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Germany']
# ['ERIAC']
# ['Switzerland']
# ['Association Films Plans-Fixes']
# ['Italy']
# ['Braidense National Library']
# ['Italy']
# ['Braidense National Library']
# ['Italy']
# ['Braidense National Library']
# ['Czech Republic']
# ['Historical Museum']
# ['Germany']
# ['Deutsche Fotothek']
# ['Italy']
# ['Braidense National Library']
# ['Italy']
# ['Central Institute for the Union Catalogue of Italian Libraries']
# ['Germany']
# ['Deutsche Fotothek']
# ['Estonia']
# ['Under and Tuglas Literature Centre']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bibliotheca Hertziana – Max Planck Institut for Art History']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Germany']
# ['Bavarian State Library']
# ['Spain']
# ['Sancho el Sabio Foundation']
# ['Germany']
# ['Museum Ludwig, Cologne']
# ['Germany']
# ['Museum Ludwig, Cologne']
# ['Italy']
# ['MuseiD-Italia']
# ['Italy']
# ['MuseiD-Italia']
# ['Italy']
# ['MuseiD-Italia']
# ['Italy']
# ['Turin Gallery for Modern and Contemporary Art']
# ['Netherlands']
# ['Jewish Historical Museum']
# ['Netherlands']
# ['Jewish Historical Museum']
# ['Belgium']
# ['Meise Botanic Garden']
# ['Germany']
# ['Digital Art and Culture Archive Düsseldorf']
# ['Germany']
# ['Digital Art and Culture Archive Düsseldorf']
# ['Germany']
# ['Kunstbibliothek Berlin']
# ['Sweden']
# ['The Royal Armoury']
# ['Sweden']
# ['The Royal Armoury']
# ['Sweden']
# ['The Royal Armoury']
# ['Sweden']
# ['The Royal Armoury']
# ['Sweden']
# ['Modern Art Museum']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['Germany']
# ['Heidelberg University Library']
# ['France']
# ['Rhône-Alpes Laboratory for Historical Research']
# ['France']
# ['Rhône-Alpes Laboratory for Historical Research']
# ['France']
# ['Rhône-Alpes Laboratory for Historical Research']
# ['France']
# ['Rhône-Alpes Laboratory for Historical Research']
# ['Italy']
# ['Internet Culturale']
# ['Italy']
# ['Internet Culturale']
# ['Italy']
# ['Internet Culturale']
# ['Italy']
# ['Internet Culturale']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Netherlands']
# ['IMSLP/Petrucci Music Library']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Luce Institute']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Deutsche Welle']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Austrian Broadcasting Corporation']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['National Audiovisual Archive of Hungary']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['Europe']
# ['Czech Televison']
# ['France']
# ['National Audiovisual Institute France']
# ['Germany']
# ['Deutsche Welle']
# ['Germany']
# ['Deutsche Welle']
# ['Germany']
# ['Deutsche Welle']
# ['Germany']
# ['Deutsche Welle']
# ['Germany']
# ['Deutsche Welle']
# ['Germany']
# ['GESIS - Leibniz Institute for the Social Sciences. Library Cologne']
# ['Netherlands']
# ['Allard Pierson']
# ['Netherlands']
# ['Allard Pierson']
# ['Spain']
# ['The Digital Network of Museum Collections in Spain']
# ['Spain']
# ['The Digital Network of Museum Collections in Spain']
# ['Spain']
# ['The Digital Network of Museum Collections in Spain']
# ['Spain']
# ['The Digital Network of Museum Collections in Spain']
# ['Spain']
# ['The Digital Network of Museum Collections in Spain']
# ['Spain']
# ['The Digital Network of Museum Collections in Spain']
# ['Spain']
# ['The Digital Network of Museum Collections in Spain']
# ['Spain']
# ['The Digital Network of Museum Collections in Spain']
# ['Germany']
# ['German Documentation Center for Art History - Marburg Picture Index']
# ['Germany']
# ['German Documentation Center for Art History - Marburg Picture Index']
# ['Romania']
# ['National Heritage Institute, Bucharest']
# ['Italy']
# ['Luigi Sturzo Institute']
# ['Bulgaria']
# ['Central Library of the Bulgarian Academy of Sciences']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Institute for Cultural Heritage']
# ['Belgium']
# ['Royal Museums of Fine Arts of Belgium']
# ['United Kingdom']
# ['TopFoto']
# ['Europe']
# ["Centre for History and Analysis of Recorded Music, King's College London; United Kingdom"]
# ['Belgium']
# ['M Leuven']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['National Library of Spain']
# ['Spain']
# ['Institute of Cultural Heritage of Spain']
# ['Spain']
# ['Institute of Cultural Heritage of Spain']
# ['Spain']
# ['Institute of Cultural Heritage of Spain']
# ['Spain']
# ['Institute of Cultural Heritage of Spain']
# ['Spain']
# ['Institute of Cultural Heritage of Spain']
# ['Netherlands']
# ['Archives of North Holland']
# ['Netherlands']
# ['Archives of North Holland']
# ['Netherlands']
# ['Historic Center Leeuwarden']
# ['Netherlands']
# ["City Archives' s-Hertogenbosch"]
# ['Netherlands']
# ["City Archives' s-Hertogenbosch"]
# ['Netherlands']
# ["City Archives' s-Hertogenbosch"]
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Rotterdam City Archives']
# ['Netherlands']
# ['Institute for War-, Holocaust- and Genocidestudies']
# ['Netherlands']
# ['Teylers Museum']
# ['Netherlands']
# ['Teylers Museum']
# ['Netherlands']
# ['Teylers Museum']
# ['Netherlands']
# ['Teylers Museum']
# ['Netherlands']
# ['Teylers Museum']
# ['Europe']
# ['Europeana 1914-1918']
# ['Germany']
# ['German Documentation Center for Art History - Marburg Picture Index']
# ['Germany']
# ['German Documentation Center for Art History - Marburg Picture Index']
# ['Germany']
# ['German Documentation Center for Art History - Marburg Picture Index']
# ['Germany']
# ['German Documentation Center for Art History - Marburg Picture Index']
# ['Germany']
# ['German Documentation Center for Art History - Marburg Picture Index']
# ['Germany']
# ['Deutsche Fotothek']
# ['Austria']
# ['MAK – Museum of Applied Arts']
# ['Austria']
# ['MAK – Museum of Applied Arts']
# ['Austria']
# ['MAK – Museum of Applied Arts']
# ['Austria']
# ['MAK – Museum of Applied Arts']
# ['Austria']
# ['Albertina']
# ['Austria']
# ['Albertina']
# ['Austria']
# ['Albertina']
# ['Austria']
# ['Albertina']
# ['Austria']
# ['Albertina']
# ['Austria']
# ['Albertina']
# ['Austria']
# ['Albertina']
# ['Greece']
# ['Aikaterini Laskaridis Foundation']
# ['Greece']
# ['Hellenic Literary and Historical Archive - Cultural Foundation of the National Bank Of Greece']
# ['Greece']
# ['Hellenic Literary and Historical Archive - Cultural Foundation of the National Bank Of Greece']
# ['Greece']
# ['Hellenic Literary and Historical Archive - Cultural Foundation of the National Bank Of Greece']
# ['Greece']
# ['Hellenic Literary and Historical Archive - Cultural Foundation of the National Bank Of Greece']
# ['Czech Republic']
# ['Municipal Library of Prague']
# ['Czech Republic']
# ['Municipal Library of Prague']
# ['Czech Republic']
# ['Municipal Library of Prague']
# ['Czech Republic']
# ['Municipal Library of Prague']
# ['Czech Republic']
# ['Municipal Library of Prague']
# ['Netherlands']
# ['Naturalis Biodiversity Center']
# ['Portugal']
# ['National Library of Portugal']
# ['Portugal']
# ['Madeira Arts Library']
# ['Portugal']
# ['National Library of Portugal']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Netherlands']
# ['National Library of the Netherlands']
# ['Poland']
# ['West Pomeranian Digital Library "Pomerania"']
# ['Poland']
# ['Silesian Digital Library']
# ['Poland']
# ['Pomeranian Digital Library']
# ['Poland']
# ['Mazowsze Digital Library']
# ['Poland']
# ['E-library of Warsaw University']
# ['United States of America']
# ['Leo Baeck Institute, Center for Jewish History']
# ['Spain']
# ['Catalunya Film Archive']
# ['Belgium']
# ['The Royal Belgian Film Archives']
# ['Czech Republic']
# ['National Film Archive']
# ['Czech Republic']
# ['National Film Archive']
# ['Finland']
# ['National Audiovisual Institute']
# ['Germany']
# ['Museum of City History Leipzig']
# ['France']
# ['National Audiovisual Institute France']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Ghent University Library']
# ['Belgium']
# ['Royal Museum of Fine Arts Antwerp']
# ['Belgium']
# ['Royal Museum of Fine Arts Antwerp']
# ['Belgium']
# ['Museum of Fine Arts Ghent']
# ['Belgium']
# ['Museum of Fine Arts Ghent']
# ['Belgium']
# ['Royal Museum of Fine Arts Antwerp']
# ['France']
# ['Interuniversity Health Library']
# ['France']
# ['Interuniversity Health Library']
# ['France']
# ['Interuniversity Health Library']
# ['France']
# ['Interuniversity Health Library']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['Ministry of Culture']
# ['France']
# ['National Archives of France']
# ['France']
# ['National Archives of France']
# ['France']
# ['National Archives of France']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Media Library of Architecture and Heritage']
# ['France']
# ['Philharmonie de Paris']

# %%
dict(sorted(count_data_provider.items(), key=lambda item: item[1]))
# Out:
# {'National Szechenyi Library': 1,
#  'Wellcome Collection': 1,
#  'Lucian Blaga Central University Library, Cluj-Napoca, Romania': 1,
#  'The University and National Library of Debrecen': 1,
#  'Uppsala University': 1,
#  'Örebro County Museum': 1,
#  'Digital Memory of Catalonia': 1,
#  'Association Films Plans-Fixes': 1,
#  'Historical Museum': 1,
#  'Central Institute for the Union Catalogue of Italian Libraries': 1,
#  'Under and Tuglas Literature Centre': 1,
#  'Bibliotheca Hertziana – Max Planck Institut for Art History': 1,
#  'Sancho el Sabio Foundation': 1,
#  'Turin Gallery for Modern and Contemporary Art': 1,
#  'Meise Botanic Garden': 1,
#  'Kunstbibliothek Berlin': 1,
#  'Modern Art Museum': 1,
#  'Luce Institute': 1,
#  'Austrian Broadcasting Corporation': 1,
#  'National Audiovisual Archive of Hungary': 1,
#  'GESIS - Leibniz Institute for the Social Sciences. Library Cologne': 1,
#  'National Heritage Institute, Bucharest': 1,
#  'Luigi Sturzo Institute': 1,
#  'Central Library of the Bulgarian Academy of Sciences': 1,
#  'Royal Museums of Fine Arts of Belgium': 1,
#  'TopFoto': 1,
#  "Centre for History and Analysis of Recorded Music, King's College London; United Kingdom": 1,
#  'M Leuven': 1,
#  'Historic Center Leeuwarden': 1,
#  'Rotterdam City Archives': 1,
#  'Europeana 1914-1918': 1,
#  'Aikaterini Laskaridis Foundation': 1,
#  'Naturalis Biodiversity Center': 1,
#  'Madeira Arts Library': 1,
#  'West Pomeranian Digital Library "Pomerania"': 1,
#  'Silesian Digital Library': 1,
#  'Pomeranian Digital Library': 1,
#  'Mazowsze Digital Library': 1,
#  'E-library of Warsaw University': 1,
#  'Leo Baeck Institute, Center for Jewish History': 1,
#  'Catalunya Film Archive': 1,
#  'The Royal Belgian Film Archives': 1,
#  'National Audiovisual Institute': 1,
#  'Museum of City History Leipzig': 1,
#  'Philharmonie de Paris': 1,
#  'National Institute for Art History Library': 2,
#  'Baden State Library': 2,
#  'Museum Ludwig, Cologne': 2,
#  'Jewish Historical Museum': 2,
#  'Digital Art and Culture Archive Düsseldorf': 2,
#  'National Audiovisual Institute France': 2,
#  'Allard Pierson': 2,
#  'Archives of North Holland': 2,
#  'Institute for War-, Holocaust- and Genocidestudies': 2,
#  'National Library of Portugal': 2,
#  'National Film Archive': 2,
#  'Museum of Fine Arts Ghent': 2,
#  'Deutsche Fotothek': 3,
#  'MuseiD-Italia': 3,
#  "City Archives' s-Hertogenbosch": 3,
#  'Royal Museum of Fine Arts Antwerp': 3,
#  'National Archives of France': 3,
#  'Braidense National Library': 4,
#  'The Royal Armoury': 4,
#  'Rhône-Alpes Laboratory for Historical Research': 4,
#  'Internet Culturale': 4,
#  'MAK – Museum of Applied Arts': 4,
#  'Hellenic Literary and Historical Archive - Cultural Foundation of the National Bank Of Greece': 4,
#  'Interuniversity Health Library': 4,
#  'Bodleian Libraries, University of Oxford': 5,
#  'Institute of Cultural Heritage of Spain': 5,
#  'Teylers Museum': 5,
#  'Municipal Library of Prague': 5,
#  'National Library of the Czech Republic': 6,
#  'Deutsche Welle': 6,
#  'German Documentation Center for Art History - Marburg Picture Index': 7,
#  'Albertina': 7,
#  'Ghent University Library': 8,
#  'The Digital Network of Museum Collections in Spain': 8,
#  'Rijksmuseum': 9,
#  'Russian State Library': 11,
#  'City of Music': 11,
#  'National Library of Poland': 12,
#  'Herzog Anton Ulrich Museum': 12,
#  'Austrian National Library': 17,
#  'Heidelberg University Library': 17,
#  'National Library of the Netherlands': 18,
#  'Media Library of Architecture and Heritage': 18,
#  'Royal Institute for Cultural Heritage': 19,
#  'Czech Televison': 22,
#  'Ministry of Culture': 22,
#  'IMSLP/Petrucci Music Library': 36,
#  'Bavarian State Library': 39,
#  'National Library of Spain': 43,
#  'ERIAC': 298,
#  'National Library of France': 312}
